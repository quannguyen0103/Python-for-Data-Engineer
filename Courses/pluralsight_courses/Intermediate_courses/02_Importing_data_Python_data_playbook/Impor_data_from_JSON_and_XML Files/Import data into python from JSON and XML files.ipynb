# %%
#JASON: Java Script Object Notation
# JASON is a collection of key-value pairs like dictionary
import json #json library

# %%
#load the json files using load or loads functions
with open("posts-100.json") as f:
    post_json = json.load(f)

# %%
#post_json is now a list of dictionaries
post_json
# Out:
# [{'Id': 5,
#   'PostTypeId': '1',
#   'CreationDate': '2014-05-13T23:58:30.457',
#   'Score': 9,
#   'ViewCount': 448,
#   'LastActivityDate': '2014-05-14T00:36:31.077',
#   'Title': 'How can I do simple machine learning without hard-coding behavior?',
#   'Tags': '<machine-learning>',
#   'AnswerCount': 1,
#   'CommentCount': 1,
#   'FavoriteCount': 1,
#   'ClosedDate': '2014-05-14T14:40:25.950'},
#  {'Id': 7,
#   'PostTypeId': '1',
#   'CreationDate': '2014-05-14T00:11:06.457',
#   'Score': 4,
#   'ViewCount': 388,
#   'LastActivityDate': '2014-05-16T13:45:00.237',
#   'Title': 'What open-source books (or other materials) provide a relatively thorough overview of data science?',
#   'Tags': '<education><open-source>',
#   'AnswerCount': 3,
#   'CommentCount': 4,
#   'FavoriteCount': 1,
#   'ClosedDate': '2014-05-14T08:40:54.950'},
#  {'Id': 9,
#   'PostTypeId': '2',
#   'CreationDate': '2014-05-14T00:36:31.077',
#   'Score': 5,
#   'LastActivityDate': '2014-05-14T00:36:31.077',
# ...

# %%
type(post_json)
# Out:
# list

# %%
type(post_json[0]) #value in the list is dictionaries
# Out:
# dict

# %%
#load data from XML files into Python
#XML files is a tree of root and nodes and subnodes
#first import the elementTree library
import xml.etree.ElementTree as ET
#import data using parse function
tree = ET.parse("users-100.xml")

# %%
tree #the parse only load the data into Python, if you want to import data, using getroot and getchildren

# %%
#import the root first
user_root = tree.getroot()

# %%
user_root.tag
# Out:
# 'Users'

# %%
#import the children
list(user_root)
# Out:
# [<Element 'row' at 0x00000298ACCB6AE0>,
#  <Element 'row' at 0x00000298ACCB6E50>,
#  <Element 'row' at 0x00000298ACCB6F90>,
#  <Element 'row' at 0x00000298ACCBA1D0>,
#  <Element 'row' at 0x00000298ACCBA360>,
#  <Element 'row' at 0x00000298ACCBA540>,
#  <Element 'row' at 0x00000298ACCBA770>,
#  <Element 'row' at 0x00000298ACCBA950>,
#  <Element 'row' at 0x00000298ACCBAB80>,
#  <Element 'row' at 0x00000298ACCBAD60>,
#  <Element 'row' at 0x00000298ACCBAEF0>,
#  <Element 'row' at 0x00000298ACCBB180>,
#  <Element 'row' at 0x00000298ACCBB360>,
#  <Element 'row' at 0x00000298ACCBB4A0>,
#  <Element 'row' at 0x00000298ACCBB630>,
#  <Element 'row' at 0x00000298ACCBB810>,
#  <Element 'row' at 0x00000298ACCBB9A0>,
#  <Element 'row' at 0x00000298ACCBBBD0>,
#  <Element 'row' at 0x00000298ACCBBD60>,
#  <Element 'row' at 0x00000298ACCBBEA0>,
#  <Element 'row' at 0x00000298ACCBF0E0>,
#  <Element 'row' at 0x00000298ACCBF220>,
#  <Element 'row' at 0x00000298ACCBF450>,
# ...
