# %%
# Transactional processing:
# 1. Ensure correctness of individual entries
# 2. Acess to recent data, from the last few hours of days
# 3. Updates data
# 4. Fast real time access
# 5. Usually a single data source

# %%
#Analytical processing:
# 1. Analyzes large batches of data
# 2. Acess to older data (going back months, or even years)
# 3. Mostly reads data
# 4. Long running jobs
# 5. Multiple data source
