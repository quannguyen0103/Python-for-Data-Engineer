# %%
# !ls
# Out:
#  ChangeTheme.ipynb
# '[Python for DA] - Commend Line Processes and Environment Variables.ipynb'
#  anaconda3

# %%
# !grep
# Out:
# Usage: grep [OPTION]... PATTERNS [FILE]...
# Try 'grep --help' for more information.
